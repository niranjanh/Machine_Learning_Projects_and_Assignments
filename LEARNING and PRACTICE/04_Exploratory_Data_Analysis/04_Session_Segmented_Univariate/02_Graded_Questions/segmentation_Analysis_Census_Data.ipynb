# %%
import pandas as pd
import numpy as np

# %%
census_df = pd.read_csv("./EDA_census_formatted.csv")
census_df.head(10)
# Out:
#   Table Name  State Code  Distt. Code Area Name  Total Age-group  \
# 0      C2308           0            0     INDIA  Total  All ages
# 1      C2308           0            0     INDIA  Total       0-6
# 2      C2308           0            0     INDIA  Total         7
# 3      C2308           0            0     INDIA  Total         8
# 4      C2308           0            0     INDIA  Total         9
# 5      C2308           0            0     INDIA  Total        10
# 6      C2308           0            0     INDIA  Total        11
# 7      C2308           0            0     INDIA  Total        12
# 8      C2308           0            0     INDIA  Total        13
# 9      C2308           0            0     INDIA  Total        14
#
#    Total Person  Total Males  Total Females  Illiterate Persons  \
# 0    1210854977    623270258      587584719           447216165
# 1     164515253     85752254       78762999           164515253
# ...

# %% [markdown]
# ## Segmented Analysis

# %% [markdown]
# ### QUES 1: What percentage of females in the age group 20-24 are illiterate in India, i.e. out of all the females in the age group 20-24, what fraction is illiterate?

# %%
# watch_tv_pivot_table = pd.pivot_table(nas_df, columns = ["Watch.TV"], values="Science..", aggfunc=np.mean)

census_illiterate_females_pivot_table = pd.pivot_table(census_df, columns=["Age-group"], values="Illiterate Females", aggfunc=np.sum)
census_illiterate_females_pivot_table
# Out:
# Age-group                 0-6       10       11       12       13       14  \
# Illiterate Females  315051996  7173524  4236580  5216836  4078212  4721300
#
# Age-group                15       16       17       18  ...     60-64  \
# Illiterate Females  5693324  5606436  4633656  8783148  ...  51858856
#
# Age-group              65-69         7     70-74     75-79        8       80+  \
# Illiterate Females  38737896  13438124  28795488  13882028  8470688  17735820
#
# Age-group                 9  Age not stated    All ages
# Illiterate Females  5174260         3700380  1034838116
#
# [1 rows x 29 columns]

# %%
census_df["Total Females"]
# ["Age-group" == "20-24"]
# Out:
# 0       587584719
# 1        78762999
# 2        11923276
# 3        12906436
# 4        11209653
#           ...
# 3127          804
# 3128          502
# 3129          302
# 3130          329
# 3131           94
# Name: Total Females, Length: 3132, dtype: int64

# %%
census_df[(census_df["Age-group"] == "20-24") & (census_df["Total"] == "Total") & (census_df["Area Name"] == "INDIA")]
# Out:
#    Table Name  State Code  Distt. Code Area Name  Total Age-group  \
# 15      C2308           0            0     INDIA  Total     20-24
#
#     Total Person  Total Males  Total Females  Illiterate Persons  \
# 15     111424222     57584693       53839529            18679492
#
#     Illiterate Males  Illiterate Females  Literate Persons  Literate Males  \
# 15           6467026            12212466          92744730        51117667
#
#     Literate Females
# 15          41627063

# %%
perc = 12212466/53839529
perc
# Out:
# 0.22683084764727418

# %% [markdown]
# ### ANS:  22.7 %

# %% [markdown]
# ### QUES 2: Compare the literacy rates (i.e. the number of literates / total number of population) in each age group and choose the correct option.

# %%
census_df.head(100)
# Out:
#    Table Name  State Code  Distt. Code                Area Name  Total  \
# 0       C2308           0            0                    INDIA  Total
# 1       C2308           0            0                    INDIA  Total
# 2       C2308           0            0                    INDIA  Total
# 3       C2308           0            0                    INDIA  Total
# 4       C2308           0            0                    INDIA  Total
# ..        ...         ...          ...                      ...    ...
# 95      C2308           1            0  State - JAMMU & KASHMIR  Total
# 96      C2308           1            0  State - JAMMU & KASHMIR  Total
# 97      C2308           1            0  State - JAMMU & KASHMIR  Total
# 98      C2308           1            0  State - JAMMU & KASHMIR  Total
# 99      C2308           1            0  State - JAMMU & KASHMIR  Total
#
#    Age-group  Total Person  Total Males  Total Females  Illiterate Persons  \
# ...

# %%
# watch_tv_pivot_table = pd.pivot_table(nas_df, columns = ["Watch.TV"], values="Science..", aggfunc=np.mean)
# {"Illiterate Persons"/ "Total Person"}

def divideNum(a, b):
    if b == 0:
        return 0
    else:
        return a/b

#     aggfunc= divideNum("Total Person", "Illiterate Persons")
# index=["Area Name"],

census_literate_rate_all_age_groups = pd.pivot_table(census_df, columns=["Age-group"], values=["Illiterate Persons", "Total Person"], aggfunc= np.subtract)
census_literate_rate_all_age_groups
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     959                 try:
# --> 960                     result = self._aggregate_multiple_funcs([func], _axis=self.axis)
#     961                 except ValueError as err:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _axis)
#     550         if not len(results):
# --> 551             raise ValueError("no results")
#     552
#
# ValueError: no results
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-8b233b8aacaa> in <module>()
#      11 # index=["Area Name"],
#      12
# ...

# %% [markdown]
# ### QUES 3: Which state shows the highest female literacy rate?

# %%
census_df.head(10)
# Out:
#   Table Name  State Code  Distt. Code Area Name  Total Age-group  \
# 0      C2308           0            0     INDIA  Total  All ages
# 1      C2308           0            0     INDIA  Total       0-6
# 2      C2308           0            0     INDIA  Total         7
# 3      C2308           0            0     INDIA  Total         8
# 4      C2308           0            0     INDIA  Total         9
# 5      C2308           0            0     INDIA  Total        10
# 6      C2308           0            0     INDIA  Total        11
# 7      C2308           0            0     INDIA  Total        12
# 8      C2308           0            0     INDIA  Total        13
# 9      C2308           0            0     INDIA  Total        14
#
#    Total Person  Total Males  Total Females  Illiterate Persons  \
# 0    1210854977    623270258      587584719           447216165
# 1     164515253     85752254       78762999           164515253
# ...

# %%
census_states_literacy_rate = pd.pivot_table(census_df, index=["State Code", "Area Name"], values=["Literate Females", "Total Females"])
census_states_literacy_rate
# Out:
#                                               Literate Females  Total Females
# State Code Area Name
# 0          INDIA                                  1.512070e+07   2.701539e+07
# 1          State - JAMMU & KASHMIR                1.288534e+05   2.712938e+05
# 2          State - HIMACHAL PRADESH               1.051561e+05   1.555278e+05
# 3          State - PUNJAB                         3.802796e+05   6.024769e+05
# 4          State - CHANDIGARH                     1.563641e+04   2.182929e+04
# 5          State - UTTARAKHAND                    1.387239e+05   2.275181e+05
# 6          State - HARYANA                        3.128699e+05   5.451369e+05
# 7          State - NCT OF DELHI                   2.548465e+05   3.586490e+05
# 8          State - RAJASTHAN                      6.706607e+05   1.517124e+06
# 9          State - UTTAR PRADESH                  2.122418e+06   4.383073e+06
# 10         State - BIHAR                          9.607600e+05   2.290634e+06
# ...

# %%
census_df[census_df["State Code"]  == 31]
# Out:
#      Table Name  State Code  Distt. Code            Area Name  Total  \
# 2697      C2308          31            0  State - LAKSHADWEEP  Total
# 2698      C2308          31            0  State - LAKSHADWEEP  Total
# 2699      C2308          31            0  State - LAKSHADWEEP  Total
# 2700      C2308          31            0  State - LAKSHADWEEP  Total
# 2701      C2308          31            0  State - LAKSHADWEEP  Total
# ...         ...         ...          ...                  ...    ...
# 2779      C2308          31            0  State - LAKSHADWEEP  Urban
# 2780      C2308          31            0  State - LAKSHADWEEP  Urban
# 2781      C2308          31            0  State - LAKSHADWEEP  Urban
# 2782      C2308          31            0  State - LAKSHADWEEP  Urban
# 2783      C2308          31            0  State - LAKSHADWEEP  Urban
#
#            Age-group  Total Person  Total Males  Total Females  \
# 2697        All ages         64473        33123          31350
# ...

# %%
census_df[census_df["State Code"]  == 2]
# Out:
#     Table Name  State Code  Distt. Code                 Area Name  Total  \
# 174      C2308           2            0  State - HIMACHAL PRADESH  Total
# 175      C2308           2            0  State - HIMACHAL PRADESH  Total
# 176      C2308           2            0  State - HIMACHAL PRADESH  Total
# 177      C2308           2            0  State - HIMACHAL PRADESH  Total
# 178      C2308           2            0  State - HIMACHAL PRADESH  Total
# ..         ...         ...          ...                       ...    ...
# 256      C2308           2            0  State - HIMACHAL PRADESH  Urban
# 257      C2308           2            0  State - HIMACHAL PRADESH  Urban
# 258      C2308           2            0  State - HIMACHAL PRADESH  Urban
# 259      C2308           2            0  State - HIMACHAL PRADESH  Urban
# 260      C2308           2            0  State - HIMACHAL PRADESH  Urban
#
#           Age-group  Total Person  Total Males  Total Females  \
# ...

# %%
census_df[census_df["State Code"]  == 4]
# Out:
#     Table Name  State Code  Distt. Code           Area Name  Total  \
# 348      C2308           4            0  State - CHANDIGARH  Total
# 349      C2308           4            0  State - CHANDIGARH  Total
# 350      C2308           4            0  State - CHANDIGARH  Total
# 351      C2308           4            0  State - CHANDIGARH  Total
# 352      C2308           4            0  State - CHANDIGARH  Total
# ..         ...         ...          ...                 ...    ...
# 430      C2308           4            0  State - CHANDIGARH  Urban
# 431      C2308           4            0  State - CHANDIGARH  Urban
# 432      C2308           4            0  State - CHANDIGARH  Urban
# 433      C2308           4            0  State - CHANDIGARH  Urban
# 434      C2308           4            0  State - CHANDIGARH  Urban
#
#           Age-group  Total Person  Total Males  Total Females  \
# 348        All ages       1055450       580663         474787
# ...
