# %% [markdown]
# Download the data set about the batting figures of batsmen in ODI matches given below. Analyse the data.
#
# Choose strike rate and average as the two factors on which you will cluster the data.
#
# You don’t need to clean the data.
#
# Just scale the data using the scale command and create the clusters.
#
#
# Pointers before you proceed:
#
# 1. standardise all parameters using standard_scaler.fit_transform() and save the output to a variable before you proceed.
#
# 2. Choose random_state=100 for running K-Means in Python with SKLearn.

# %%
#Importing Libraries
import pandas as pd

# For Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# To Scale our data
from sklearn.preprocessing import scale

# To perform KMeans clustering 
from sklearn.cluster import KMeans

# To perform Hierarchical clustering
# from scipy.cluster.hierarchy import linkage
# from scipy.cluster.hierarchy import dendrogram
# from scipy.cluster.hierarchy import cut_tree

# %%
cricket = pd.read_csv("Cricket.csv",  sep = ',',encoding = "ISO-8859-1", header= 0)

# %%
cricket.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %%
cricket.shape
# Out:
# (79, 13)

# %% [markdown]
# ### filtering data

# %%
cricket = cricket[["Player", "Ave", "SR"]]

# %%
cricket.shape
# Out:
# (79, 3)

# %%
cricket.head()
# Out:
#                         Player    Ave     SR
# 0         SR Tendulkar (INDIA)  44.83  86.23
# 1  KC Sangakkara (Asia/ICC/SL)  41.98  78.86
# 2         RT Ponting (AUS/ICC)  42.03  80.39
# 3      ST Jayasuriya (Asia/SL)  32.36  91.20
# 4   DPMD Jayawardene (Asia/SL)  33.37  78.96

# %% [markdown]
# ### Scaling Data

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()

# %%
num_vars = ["Ave", "SR"]
cricket[num_vars] = standard_scaler.fit_transform(cricket[num_vars])
# Out:
# /home/niranjan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/niranjan/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
cricket.shape
# Out:
# (79, 3)

# %%
cricket.head()
# Out:
#                         Player       Ave        SR
# 0         SR Tendulkar (INDIA)  1.072294  0.703152
# 1  KC Sangakkara (Asia/ICC/SL)  0.587725 -0.044139
# 2         RT Ponting (AUS/ICC)  0.596226  0.110997
# 3      ST Jayasuriya (Asia/SL) -1.047909  1.207091
# 4   DPMD Jayawardene (Asia/SL) -0.876185 -0.034000

# %% [markdown]
# ## K-means

# %%
from sklearn.metrics import silhouette_score
sse_ = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k).fit(cricket[num_vars])
    sse_.append([k, silhouette_score(cricket[num_vars], kmeans.labels_)])

# %%
plt.plot(pd.DataFrame(sse_)[0], pd.DataFrame(sse_)[1]);

# %% [markdown]
# ### Optimal value of k = 8

# %%
model_clus = KMeans(n_clusters = 8, max_iter=50)
model_clus.fit(cricket[num_vars])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=50,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# RFM.index = pd.RangeIndex(len(RFM.index))
# RFM_km = pd.concat([RFM, pd.Series(model_clus5.labels_)], axis=1)
# RFM_km.columns = ['CustomerID', 'Frequency', 'Amount', 'Recency', 'ClusterID']

# %%
model_clus.labels_
# Out:
# array([1, 4, 4, 3, 2, 4, 4, 4, 7, 4, 1, 4, 3, 5, 2, 5, 2, 1, 4, 7, 1, 7,
#        7, 4, 3, 5, 2, 6, 0, 4, 2, 2, 7, 2, 5, 2, 2, 2, 5, 7, 2, 2, 5, 0,
#        2, 0, 4, 0, 2, 4, 3, 4, 7, 2, 2, 0, 4, 1, 2, 1, 2, 3, 4, 1, 5, 1,
#        2, 7, 4, 2, 1, 0, 2, 0, 7, 4, 2, 1, 2], dtype=int32)

# %%
cricket.index = pd.RangeIndex(len(cricket.index))
cricket_km = pd.concat([cricket, pd.Series(model_clus.labels_)], axis=1)
cricket_km.columns = ['Player', 'Ave', 'SR', 'ClusterID']

# %%
cricket_km.shape
# Out:
# (79, 4)

# %%
cricket_km.head()
# Out:
#                         Player       Ave        SR  ClusterID
# 0         SR Tendulkar (INDIA)  1.072294  0.703152          1
# 1  KC Sangakkara (Asia/ICC/SL)  0.587725 -0.044139          4
# 2         RT Ponting (AUS/ICC)  0.596226  0.110997          4
# 3      ST Jayasuriya (Asia/SL) -1.047909  1.207091          3
# 4   DPMD Jayawardene (Asia/SL) -0.876185 -0.034000          2

# %%
cricket_km_gb_cluster = cricket_km.groupby("ClusterID")
cricket_km_gb_cluster.head()
# Out:
#                           Player       Ave        SR  ClusterID
# 0           SR Tendulkar (INDIA)  1.072294  0.703152          1
# 1    KC Sangakkara (Asia/ICC/SL)  0.587725 -0.044139          4
# 2           RT Ponting (AUS/ICC)  0.596226  0.110997          4
# 3        ST Jayasuriya (Asia/SL) -1.047909  1.207091          3
# 4     DPMD Jayawardene (Asia/SL) -0.876185 -0.034000          2
# 5      Inzamam-ul-Haq (Asia/PAK)  0.169465 -0.512591          4
# 6         JH Kallis (Afr/ICC/SA)  0.992383 -0.649476          4
# 7        SC Ganguly (Asia/INDIA)  0.424501 -0.567345          4
# 8      R Dravid (Asia/ICC/INDIA)  0.108256 -0.816780          7
# 10               TM Dilshan (SL)  0.126959  0.703152          1
# 12        AC Gilchrist (AUS/ICC) -0.447724  1.789106          3
# 13         MS Dhoni (Asia/INDIA)  2.175752  0.952587          5
# 14          M Azharuddin (INDIA) -0.272599 -0.534898          2
# 15       AB de Villiers (Afr/SA)  2.554906  2.124728          5
# 16              PA de Silva (SL) -0.616048  0.186030          2
# 17             CH Gayle (ICC/WI) -0.202889  0.589588          1
# 19            S Chanderpaul (WI)  0.523115 -0.867478          7
# 20     Yuvraj Singh (Asia/INDIA) -0.335508  0.849162          1
# 21                DL Haynes (WI)  0.484010 -1.643160          7
# 22              MS Atapattu (SL) -0.162083 -1.173695          7
# 24     V Sehwag (Asia/ICC/INDIA) -0.590544  2.538425          3
# 25               V Kohli (INDIA)  2.621216  1.185798          5
# 26                 HH Gibbs (SA) -0.406918  0.402004          2
# 27  Shahid Afridi (Asia/ICC/PAK) -2.542423  3.823117          6
# 28           SP Fleming (ICC/NZ) -1.041108 -0.791431          0
# 30                SR Waugh (AUS) -0.956096 -0.343259          2
# 32           Javed Miandad (PAK)  0.540118 -1.245686          7
# 34                  HM Amla (SA)  1.993826  0.989089          5
# 38                MG Bevan (AUS)  2.560007 -0.520702          5
# 43               GW Flower (ZIM) -0.850681 -1.187890          0
# 45               AR Border (AUS) -1.343752 -0.798528          0
# 47            RB Richardson (WI) -0.869384 -1.577252          0
# 50              BB McCullum (NZ) -1.379457  1.731310          3
# 55             Rameez Raja (PAK) -1.093816 -1.620853          0
# 57          EJG Morgan (ENG/IRE)  0.035146  0.945489          1
# 61              SK Raina (INDIA) -0.520834  1.466666          3

# %%
cricket_km.pivot_table(columns=["ClusterID"], )
# Out:
# ClusterID         0         1         2         3         4         5  \
# Ave       -1.156968  0.292562 -0.679104 -0.797294  0.573923  2.140533
# SR        -1.314925  0.824624 -0.168857  1.746520 -0.235838  0.947806
#
# ClusterID         6         7
# Ave       -2.542423  0.286782
# SR         3.823117 -1.148796

# %%
# k = 4

model_clus4 = KMeans(n_clusters = 4, max_iter=50)
model_clus4.fit(cricket[num_vars])

cricket.index = pd.RangeIndex(len(cricket.index))
cricket_km4 = pd.concat([cricket, pd.Series(model_clus4.labels_)], axis=1)
cricket_km4.columns = ['Player', 'Ave', 'SR', 'ClusterID']

pd.set_option("max_rows", 100)

cricket_km4.head(80)
# Out:
#                           Player       Ave        SR  ClusterID
# 0           SR Tendulkar (INDIA)  1.072294  0.703152          3
# 1    KC Sangakkara (Asia/ICC/SL)  0.587725 -0.044139          0
# 2           RT Ponting (AUS/ICC)  0.596226  0.110997          0
# 3        ST Jayasuriya (Asia/SL) -1.047909  1.207091          2
# 4     DPMD Jayawardene (Asia/SL) -0.876185 -0.034000          1
# 5      Inzamam-ul-Haq (Asia/PAK)  0.169465 -0.512591          0
# 6         JH Kallis (Afr/ICC/SA)  0.992383 -0.649476          0
# 7        SC Ganguly (Asia/INDIA)  0.424501 -0.567345          0
# 8      R Dravid (Asia/ICC/INDIA)  0.108256 -0.816780          0
# 9               BC Lara (ICC/WI)  0.332688  0.021768          0
# 10               TM Dilshan (SL)  0.126959  0.703152          0
# 11    Mohammad Yousuf (Asia/PAK)  0.541818 -0.425390          0
# 12        AC Gilchrist (AUS/ICC) -0.447724  1.789106          2
# 13         MS Dhoni (Asia/INDIA)  2.175752  0.952587          3
# 14          M Azharuddin (INDIA) -0.272599 -0.534898          1
# 15       AB de Villiers (Afr/SA)  2.554906  2.124728          3
# 16              PA de Silva (SL) -0.616048  0.186030          1
# 17             CH Gayle (ICC/WI) -0.202889  0.589588          0
# 18             Saeed Anwar (PAK)  0.116757  0.139388          0
# 19            S Chanderpaul (WI)  0.523115 -0.867478          0
# 20     Yuvraj Singh (Asia/INDIA) -0.335508  0.849162          2
# 21                DL Haynes (WI)  0.484010 -1.643160          0
# 22              MS Atapattu (SL) -0.162083 -1.173695          1
# 23                ME Waugh (AUS)  0.140561 -0.242876          0
# 24     V Sehwag (Asia/ICC/INDIA) -0.590544  2.538425          2
# 25               V Kohli (INDIA)  2.621216  1.185798          3
# 26                 HH Gibbs (SA) -0.406918  0.402004          1
# 27  Shahid Afridi (Asia/ICC/PAK) -2.542423  3.823117          2
# 28           SP Fleming (ICC/NZ) -1.041108 -0.791431          1
# 29               MJ Clarke (AUS)  1.029788 -0.031972          0
# 30                SR Waugh (AUS) -0.956096 -0.343259          1
# 31              A Ranatunga (SL) -0.456225 -0.141480          1
# 32           Javed Miandad (PAK)  0.540118 -1.245686          0
# 33             Younis Khan (PAK) -1.238337 -0.406124          1
# 34                  HM Amla (SA)  1.993826  0.989089          3
# 35            Saleem Malik (PAK) -0.959497 -0.292561          1
# 36                 NJ Astle (NZ) -0.612647 -0.674825          1
# 37             GC Smith (Afr/SA) -0.092373  0.153583          0
# 38                MG Bevan (AUS)  2.560007 -0.520702          3
# 39                G Kirsten (SA)  0.412600 -0.735663          0
# 40                A Flower (ZIM) -0.541237 -0.477102          1
# 41            Shoaib Malik (PAK) -0.559940  0.245854          1
# 42             IVA Richards (WI)  1.441247  1.105695          3
# 43               GW Flower (ZIM) -0.850681 -1.187890          1
# 44              Ijaz Ahmed (PAK) -1.053010  0.101871          1
# 45               AR Border (AUS) -1.343752 -0.798528          1
# 46              LRPL Taylor (NZ)  0.951577  0.277287          0
# 47            RB Richardson (WI) -0.869384 -1.577252          1
# 48         WU Tharanga (Asia/SL) -0.718062 -0.432487          1
# 49           ML Hayden (AUS/ICC)  0.897169 -0.034000          0
# 50              BB McCullum (NZ) -1.379457  1.731310          2
# 51                DM Jones (AUS)  1.034889 -0.682936          0
# 52                 DC Boon (AUS) -0.252196 -1.436311          1
# 53                JN Rhodes (SA) -0.580343  0.162709          1
# 54         Mohammad Hafeez (PAK) -0.937394 -0.376719          1
# 55             Rameez Raja (PAK) -1.093816 -1.620853          1
# 56                RR Sarwan (WI)  0.705041 -0.360496          0
# 57          EJG Morgan (ENG/IRE)  0.035146  0.945489          2
# 58                CL Hooper (WI) -0.541237 -0.270253          1
# 59               SR Watson (AUS)  0.342890  1.130030          2
# 60           Tamim Iqbal (BDESH) -0.704460 -0.099907          1
# 61              SK Raina (INDIA) -0.520834  1.466666          2
# 62                WJ Cronje (SA)  0.019843 -0.286477          0
# 63               MJ Guptill (NZ)  0.812157  0.855246          3
# 64              MEK Hussey (AUS)  1.636775  0.797450          3
# 65             RG Sharma (INDIA)  0.669336  0.533820          0
# 66                 IR Bell (ENG) -0.111075 -0.216513          0
# 67              A Jadeja (INDIA) -0.179085 -0.962790          1
# 68               DR Martyn (AUS)  0.387096 -0.158717          0
# 69              BRM Taylor (ZIM) -0.629650 -0.489269          1
# 70             G Gambhir (INDIA)  0.196669  0.603783          0
# 71            ADR Campbell (ZIM) -1.364155 -1.329845          1
# 72               MN Samuels (WI) -0.718062 -0.309798          1
# 73              RS Mahanama (SL) -1.535879 -1.898679          1
# 74             CG Greenidge (WI)  1.106299 -1.457604          0
# 75           Misbah-ul-Haq (PAK)  0.829159 -0.562275          0
# 76          PD Collingwood (ENG) -0.537836 -0.234765          1
# 77               A Symonds (AUS)  0.208570  1.332823          2
# 78       Abdul Razzaq (Asia/PAK) -1.500174  0.198198          1

# %%
cricket_km_avg = pd.DataFrame(cricket_km4.groupby(["ClusterID"]).Ave.mean())
cricket_km_avg
# Out:
#                 Ave
# ClusterID
# 0          0.466128
# 1         -0.777680
# 2         -0.627779
# 3          1.874242

# %%
cricket_km_sr = pd.DataFrame(cricket_km4.groupby(["ClusterID"]).SR.mean())
cricket_km_sr
# Out:
#                  SR
# ClusterID
# 0         -0.289938
# 1         -0.535421
# 2          1.681322
# 3          0.910338

# %%
cricket_km4.sort_values(by="ClusterID")
# Out:
#                           Player       Ave        SR  ClusterID
# 39                G Kirsten (SA)  0.412600 -0.735663          0
# 49           ML Hayden (AUS/ICC)  0.897169 -0.034000          0
# 51                DM Jones (AUS)  1.034889 -0.682936          0
# 37             GC Smith (Afr/SA) -0.092373  0.153583          0
# 32           Javed Miandad (PAK)  0.540118 -1.245686          0
# 56                RR Sarwan (WI)  0.705041 -0.360496          0
# 29               MJ Clarke (AUS)  1.029788 -0.031972          0
# 62                WJ Cronje (SA)  0.019843 -0.286477          0
# 65             RG Sharma (INDIA)  0.669336  0.533820          0
# 66                 IR Bell (ENG) -0.111075 -0.216513          0
# 23                ME Waugh (AUS)  0.140561 -0.242876          0
# 68               DR Martyn (AUS)  0.387096 -0.158717          0
# 46              LRPL Taylor (NZ)  0.951577  0.277287          0
# 19            S Chanderpaul (WI)  0.523115 -0.867478          0
# 18             Saeed Anwar (PAK)  0.116757  0.139388          0
# 17             CH Gayle (ICC/WI) -0.202889  0.589588          0
# 21                DL Haynes (WI)  0.484010 -1.643160          0
# 9               BC Lara (ICC/WI)  0.332688  0.021768          0
# 75           Misbah-ul-Haq (PAK)  0.829159 -0.562275          0
# 5      Inzamam-ul-Haq (Asia/PAK)  0.169465 -0.512591          0
# 1    KC Sangakkara (Asia/ICC/SL)  0.587725 -0.044139          0
# 74             CG Greenidge (WI)  1.106299 -1.457604          0
# 11    Mohammad Yousuf (Asia/PAK)  0.541818 -0.425390          0
# 10               TM Dilshan (SL)  0.126959  0.703152          0
# 2           RT Ponting (AUS/ICC)  0.596226  0.110997          0
# 70             G Gambhir (INDIA)  0.196669  0.603783          0
# 8      R Dravid (Asia/ICC/INDIA)  0.108256 -0.816780          0
# 7        SC Ganguly (Asia/INDIA)  0.424501 -0.567345          0
# 6         JH Kallis (Afr/ICC/SA)  0.992383 -0.649476          0
# 71            ADR Campbell (ZIM) -1.364155 -1.329845          1
# 52                 DC Boon (AUS) -0.252196 -1.436311          1
# 48         WU Tharanga (Asia/SL) -0.718062 -0.432487          1
# 47            RB Richardson (WI) -0.869384 -1.577252          1
# 76          PD Collingwood (ENG) -0.537836 -0.234765          1
# 53                JN Rhodes (SA) -0.580343  0.162709          1
# 58                CL Hooper (WI) -0.541237 -0.270253          1
# 55             Rameez Raja (PAK) -1.093816 -1.620853          1
# 60           Tamim Iqbal (BDESH) -0.704460 -0.099907          1
# 67              A Jadeja (INDIA) -0.179085 -0.962790          1
# 69              BRM Taylor (ZIM) -0.629650 -0.489269          1
# 73              RS Mahanama (SL) -1.535879 -1.898679          1
# 72               MN Samuels (WI) -0.718062 -0.309798          1
# 54         Mohammad Hafeez (PAK) -0.937394 -0.376719          1
# 45               AR Border (AUS) -1.343752 -0.798528          1
# 78       Abdul Razzaq (Asia/PAK) -1.500174  0.198198          1
# 43               GW Flower (ZIM) -0.850681 -1.187890          1
# 44              Ijaz Ahmed (PAK) -1.053010  0.101871          1
# 28           SP Fleming (ICC/NZ) -1.041108 -0.791431          1
# 22              MS Atapattu (SL) -0.162083 -1.173695          1
# 30                SR Waugh (AUS) -0.956096 -0.343259          1
# 31              A Ranatunga (SL) -0.456225 -0.141480          1
# 33             Younis Khan (PAK) -1.238337 -0.406124          1
# 35            Saleem Malik (PAK) -0.959497 -0.292561          1
# 16              PA de Silva (SL) -0.616048  0.186030          1
# 14          M Azharuddin (INDIA) -0.272599 -0.534898          1
# 4     DPMD Jayawardene (Asia/SL) -0.876185 -0.034000          1
# 40                A Flower (ZIM) -0.541237 -0.477102          1
# 41            Shoaib Malik (PAK) -0.559940  0.245854          1
# 36                 NJ Astle (NZ) -0.612647 -0.674825          1
# 26                 HH Gibbs (SA) -0.406918  0.402004          1
# 24     V Sehwag (Asia/ICC/INDIA) -0.590544  2.538425          2
# 12        AC Gilchrist (AUS/ICC) -0.447724  1.789106          2
# 20     Yuvraj Singh (Asia/INDIA) -0.335508  0.849162          2
# 3        ST Jayasuriya (Asia/SL) -1.047909  1.207091          2
# 61              SK Raina (INDIA) -0.520834  1.466666          2
# 27  Shahid Afridi (Asia/ICC/PAK) -2.542423  3.823117          2
# 59               SR Watson (AUS)  0.342890  1.130030          2
# 57          EJG Morgan (ENG/IRE)  0.035146  0.945489          2
# 50              BB McCullum (NZ) -1.379457  1.731310          2
# 77               A Symonds (AUS)  0.208570  1.332823          2
# 63               MJ Guptill (NZ)  0.812157  0.855246          3
# 25               V Kohli (INDIA)  2.621216  1.185798          3
# 34                  HM Amla (SA)  1.993826  0.989089          3
# 15       AB de Villiers (Afr/SA)  2.554906  2.124728          3
# 38                MG Bevan (AUS)  2.560007 -0.520702          3
# 13         MS Dhoni (Asia/INDIA)  2.175752  0.952587          3
# 42             IVA Richards (WI)  1.441247  1.105695          3
# 64              MEK Hussey (AUS)  1.636775  0.797450          3
# 0           SR Tendulkar (INDIA)  1.072294  0.703152          3

# %%
cricket_km4.sort_values(by="Player")
# Out:
#                           Player       Ave        SR  ClusterID
# 40                A Flower (ZIM) -0.541237 -0.477102          1
# 67              A Jadeja (INDIA) -0.179085 -0.962790          1
# 31              A Ranatunga (SL) -0.456225 -0.141480          1
# 77               A Symonds (AUS)  0.208570  1.332823          2
# 15       AB de Villiers (Afr/SA)  2.554906  2.124728          3
# 12        AC Gilchrist (AUS/ICC) -0.447724  1.789106          2
# 71            ADR Campbell (ZIM) -1.364155 -1.329845          1
# 45               AR Border (AUS) -1.343752 -0.798528          1
# 78       Abdul Razzaq (Asia/PAK) -1.500174  0.198198          1
# 50              BB McCullum (NZ) -1.379457  1.731310          2
# 9               BC Lara (ICC/WI)  0.332688  0.021768          0
# 69              BRM Taylor (ZIM) -0.629650 -0.489269          1
# 74             CG Greenidge (WI)  1.106299 -1.457604          0
# 17             CH Gayle (ICC/WI) -0.202889  0.589588          0
# 58                CL Hooper (WI) -0.541237 -0.270253          1
# 52                 DC Boon (AUS) -0.252196 -1.436311          1
# 21                DL Haynes (WI)  0.484010 -1.643160          0
# 51                DM Jones (AUS)  1.034889 -0.682936          0
# 4     DPMD Jayawardene (Asia/SL) -0.876185 -0.034000          1
# 68               DR Martyn (AUS)  0.387096 -0.158717          0
# 57          EJG Morgan (ENG/IRE)  0.035146  0.945489          2
# 70             G Gambhir (INDIA)  0.196669  0.603783          0
# 39                G Kirsten (SA)  0.412600 -0.735663          0
# 37             GC Smith (Afr/SA) -0.092373  0.153583          0
# 43               GW Flower (ZIM) -0.850681 -1.187890          1
# 26                 HH Gibbs (SA) -0.406918  0.402004          1
# 34                  HM Amla (SA)  1.993826  0.989089          3
# 66                 IR Bell (ENG) -0.111075 -0.216513          0
# 42             IVA Richards (WI)  1.441247  1.105695          3
# 44              Ijaz Ahmed (PAK) -1.053010  0.101871          1
# 5      Inzamam-ul-Haq (Asia/PAK)  0.169465 -0.512591          0
# 6         JH Kallis (Afr/ICC/SA)  0.992383 -0.649476          0
# 53                JN Rhodes (SA) -0.580343  0.162709          1
# 32           Javed Miandad (PAK)  0.540118 -1.245686          0
# 1    KC Sangakkara (Asia/ICC/SL)  0.587725 -0.044139          0
# 46              LRPL Taylor (NZ)  0.951577  0.277287          0
# 14          M Azharuddin (INDIA) -0.272599 -0.534898          1
# 23                ME Waugh (AUS)  0.140561 -0.242876          0
# 64              MEK Hussey (AUS)  1.636775  0.797450          3
# 38                MG Bevan (AUS)  2.560007 -0.520702          3
# 29               MJ Clarke (AUS)  1.029788 -0.031972          0
# 63               MJ Guptill (NZ)  0.812157  0.855246          3
# 49           ML Hayden (AUS/ICC)  0.897169 -0.034000          0
# 72               MN Samuels (WI) -0.718062 -0.309798          1
# 22              MS Atapattu (SL) -0.162083 -1.173695          1
# 13         MS Dhoni (Asia/INDIA)  2.175752  0.952587          3
# 75           Misbah-ul-Haq (PAK)  0.829159 -0.562275          0
# 54         Mohammad Hafeez (PAK) -0.937394 -0.376719          1
# 11    Mohammad Yousuf (Asia/PAK)  0.541818 -0.425390          0
# 36                 NJ Astle (NZ) -0.612647 -0.674825          1
# 16              PA de Silva (SL) -0.616048  0.186030          1
# 76          PD Collingwood (ENG) -0.537836 -0.234765          1
# 8      R Dravid (Asia/ICC/INDIA)  0.108256 -0.816780          0
# 47            RB Richardson (WI) -0.869384 -1.577252          1
# 65             RG Sharma (INDIA)  0.669336  0.533820          0
# 56                RR Sarwan (WI)  0.705041 -0.360496          0
# 73              RS Mahanama (SL) -1.535879 -1.898679          1
# 2           RT Ponting (AUS/ICC)  0.596226  0.110997          0
# 55             Rameez Raja (PAK) -1.093816 -1.620853          1
# 19            S Chanderpaul (WI)  0.523115 -0.867478          0
# 7        SC Ganguly (Asia/INDIA)  0.424501 -0.567345          0
# 61              SK Raina (INDIA) -0.520834  1.466666          2
# 28           SP Fleming (ICC/NZ) -1.041108 -0.791431          1
# 0           SR Tendulkar (INDIA)  1.072294  0.703152          3
# 59               SR Watson (AUS)  0.342890  1.130030          2
# 30                SR Waugh (AUS) -0.956096 -0.343259          1
# 3        ST Jayasuriya (Asia/SL) -1.047909  1.207091          2
# 18             Saeed Anwar (PAK)  0.116757  0.139388          0
# 35            Saleem Malik (PAK) -0.959497 -0.292561          1
# 27  Shahid Afridi (Asia/ICC/PAK) -2.542423  3.823117          2
# 41            Shoaib Malik (PAK) -0.559940  0.245854          1
# 10               TM Dilshan (SL)  0.126959  0.703152          0
# 60           Tamim Iqbal (BDESH) -0.704460 -0.099907          1
# 25               V Kohli (INDIA)  2.621216  1.185798          3
# 24     V Sehwag (Asia/ICC/INDIA) -0.590544  2.538425          2
# 62                WJ Cronje (SA)  0.019843 -0.286477          0
# 48         WU Tharanga (Asia/SL) -0.718062 -0.432487          1
# 33             Younis Khan (PAK) -1.238337 -0.406124          1
# 20     Yuvraj Singh (Asia/INDIA) -0.335508  0.849162          2

# %%
sns.barplot(x=cricket_km4.ClusterID, y=cricket_km4.groupby(["ClusterID"]).Ave.mean())

# %%
sns.barplot(x=cricket_km4.ClusterID, y=cricket_km4.groupby(["ClusterID"]).SR.mean())

# %%
km_clusters_ave = pd.DataFrame(cricket_km4.groupby(["ClusterID"]).Ave.mean())
km_clusters_sr = pd.DataFrame(cricket_km4.groupby(["ClusterID"]).SR.mean())

df = pd.concat([pd.Series([0,1,2,3]), km_clusters_ave, km_clusters_sr], axis=1)
df.columns = ["ClusterID", "Ave_mean", "SR_mean"]
df.sort_values(["Ave_mean", "SR_mean"])
df.head()
# Out:
#    ClusterID  Ave_mean   SR_mean
# 0          0  0.466128 -0.289938
# 1          1 -0.777680 -0.535421
# 2          2 -0.627779  1.681322
# 3          3  1.874242  0.910338
